# %% [markdown]
# ## Análisis Exploratorio de Datos

# %%
# Importamos las bases de datos:
from carga import df_games,df_reviews,df_items

# %% [markdown]
# ### Primero entendé los datos pibe!
#
# Primero analizá cada dataset columna x columna, cómo se podrian relacionar mutuamente. Mirate un video en el que expliquen EDA y ETL
#
# Primero ETL y despues EDA??

# %% [markdown]
# #### Games: registro de todos los juegos en Steam

# %%
df_games.tail(4)
# Out:
#            publisher                       genres                  app_name  \
# 120441        Sacada    [Casual, Indie, Strategy]  LOGistICAL: South Africa
# 120442  Laush Studio  [Indie, Racing, Simulation]             Russian Roads
# 120443      SIXNAILS              [Casual, Indie]       EXIT 2 - Directions
# 120444           NaN                          NaN               Maze Run VR
#
#                            title  \
# 120441  LOGistICAL: South Africa
# 120442             Russian Roads
# 120443       EXIT 2 - Directions
# 120444                       NaN
#
#                                                       url release_date  \
# 120441  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 120442  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 120443  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 120444  http://store.steampowered.com/app/681550/Maze_...          NaN
#
# ...

# %% [markdown]
# - **publisher**: empresa que publicadora del juego
# - **genres**: género del juego (acción, estrategia, etc.)
# - **app_name**: titulo de la aplicación
# - **title**: titulo del juego *(notar que coinciden siempre con el 'app_name')*
# - **url**: link al store
# - **release_date**: fecha de lanzamiento del juego
# - **tags**: etiquetas hechas por el usuario *(notar que muchas de las etiquetas coinciden con lo que figura en 'genres')*
# - **reviews_url**: link a las reseñas del juego
# - **specs**:
# - **price**: precio del producto
# - **early_access**: indica si el producto posee una version beta (previa al lanzamiento) a la que los consumidores puedan acceder
# - **id**: clave única de identificación del producto <---- ***PRIMARY KEY***
# - **developer**: empresa desarrolladora del juego

# %% [markdown]
# #### Reviews

# %%
df_reviews.head(3)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...

# %% [markdown]
# - **user_id**: nombre alias del usuario, es una clave única de identificacion del usuario <--- ***PRIMARY KEY***
# - **user_url**: link al perfil de Steam del usuario
# - **reviews**: reseñas realizadas por el usuario, cada registro es una LISTA de DICCIONARIOS. Cada diccionario es una reseña distinta y allí se detalla *fecha*, *clave de identificacion del juego*, la *reseña propiamente dicha* y algunos otros datos.

# %%
df_reviews['reviews'][0]
# Out:
# [{'funny': '',
#   'posted': 'Posted November 5, 2011.',
#   'last_edited': '',
#   'item_id': '1250',
#   'helpful': 'No ratings yet',
#   'recommend': True,
#   'review': 'Simple yet with great replayability. In my opinion does "zombie" hordes and team work better than left 4 dead plus has a global leveling system. Alot of down to earth "zombie" splattering fun for the whole family. Amazed this sort of FPS is so rare.'},
#  {'funny': '',
#   'posted': 'Posted July 15, 2011.',
#   'last_edited': '',
#   'item_id': '22200',
#   'helpful': 'No ratings yet',
#   'recommend': True,
#   'review': "It's unique and worth a playthrough."},
#  {'funny': '',
#   'posted': 'Posted April 21, 2011.',
#   'last_edited': '',
#   'item_id': '43110',
#   'helpful': 'No ratings yet',
#   'recommend': True,
# ...

# %% [markdown]
# #### Items

# %%
df_items.head(5)
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %% [markdown]
# - **user_id**: nombre alias del usuario, es foreign key de la tabla reviews <--- ***FOREIGN KEY***
# - **items_count**: cantidad de productos adquiridos por el usuario, tecnicamente, no es más que la cantidad de diccionarios que figuran en el campo *'items'*
# - **steam_id**: clave interna única de Steam para identificación del usuario
# - **user_url**: link al perfil de Steam del usuario
# - **items**: informacion acerca de los productos adquiridos por el usuario, cada registro es una LISTA de DICCIONARIOS. Cada diccionario contiene informacion sobre la *clave de identificacion del juego*, su *nombre*

# %%
cant_items = len(df_items['items'][0])
print(f'La cantidad de items adquiridos por el usuario es: {cant_items}')
# Out:
# La cantidad de items adquiridos por el usuario es: 277

# %%
df_items['items'][0]
# Out:
# [{'item_id': '10',
#   'item_name': 'Counter-Strike',
#   'playtime_forever': 6,
#   'playtime_2weeks': 0},
#  {'item_id': '20',
#   'item_name': 'Team Fortress Classic',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '30',
#   'item_name': 'Day of Defeat',
#   'playtime_forever': 7,
#   'playtime_2weeks': 0},
#  {'item_id': '40',
#   'item_name': 'Deathmatch Classic',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '50',
#   'item_name': 'Half-Life: Opposing Force',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '60',
#   'item_name': 'Ricochet',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '70',
#   'item_name': 'Half-Life',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '130',
#   'item_name': 'Half-Life: Blue Shift',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '300',
#   'item_name': 'Day of Defeat: Source',
#   'playtime_forever': 4733,
# ...
